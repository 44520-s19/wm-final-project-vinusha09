# %% [markdown]
# # Name: Vinusha Sandadi

# %% [markdown]
# ## Top 25 Twitter Users by Followers

# %% [markdown]
# ## Question:
# ### Retrieving users with highest number of followers, also comparing whether the top users have more number of tweets

# %% [markdown]
# ##### I used socialblade website to scrap the data and retrieved top 25 users and also visualized te data

# %%
# Importing libraries
from bs4 import BeautifulSoup
import pandas as pd
import requests

# %%
# website used for web scraping
url = "https://socialblade.com/twitter/"

# %%
# sending html requests 
html = requests.get(url)
results = html.text

# %%
print(results[:400])
# Out:
# <!DOCTYPE html>
# <head>
#         <title>Track Twitter analytics, future predictions, & Twitter usage graphs - Social Blade</title>
#         <meta name="description" content="View the daily Twitter analytics, track progress charts, view future predictions, Twitter top charts, Twitter influencers, & more!">
#         <meta name="keywords" content="Twitter statistics, Twitter analytics, daily statisti

# %% [markdown]
# ## Pickling data

# %%
import pickle
# pickling data
with open('data.pkl', 'wb') as f:
    pickle.dump(results, f)

# loading data from a pickle file
with open('data.pkl', 'rb') as f:
    new_results = pickle.load(f)
    print(type(new_results))
# Out:
# <class 'str'>

# %%
# Extracting the results from and storing it in soup 
soup = BeautifulSoup(new_results)
# printing the results in soup
print(soup)
# Out:
# <!DOCTYPE html>
# <html><head>
# <title>Track Twitter analytics, future predictions, &amp; Twitter usage graphs - Social Blade</title>
# <meta content="View the daily Twitter analytics, track progress charts, view future predictions, Twitter top charts, Twitter influencers, &amp; more!" name="description"/>
# <meta content="Twitter statistics, Twitter analytics, daily statistics, daily graphs, Twitter users, top Twitter users, top charts" name="keywords"/>
# <meta charset="utf-8"/>
# <meta content="website" property="og:type"/>
# <meta content="View the daily Twitter analytics, track progress charts, view future predictions, Twitter top charts, Twitter influencers, &amp; more!" property="og:description"/>
# <meta content="summary_large_image" name="twitter:card"/>
# <meta content="socialblade" name="twitter:site"/>
# <meta content="View the daily Twitter analytics, track progress charts, view future predictions, Twitter top charts, Twitter influencers, &amp; more!" name="twitter:description"/>
# <meta content="//socialblade.com/images/share-badge.png" property="og:image"/>
# <link href="https://socialblade.com/images/share-badge.png" rel="image_src"/>
# <meta content="http://socialblade.com/images/SocialbladeBadge.png" name="twitter:image"/>
# <meta content="Track Twitter analytics, future predictions, &amp; Twitter usage graphs - Social Blade" name="twitter:title"/>
# <meta content="urgo" name="twitter:creator"/>
# <meta content="dmisdtmthe6pj4frg" name="dailymotion-domain-verification"/>
# <script type="text/javascript">var _sf_startpt=(new Date()).getTime()</script>
# <script type="text/javascript">var beforeload = (new Date()).getTime()</script>
# <link href="//feeds.feedburner.com/SocialBlade" rel="alternate" title="RSS 2.0" type="application/rss+xml"/>
# <link href="/favicon.ico" rel="shortcut icon" type="image/x-icon"/>
# <link href="/apple-touch-icon.png" rel="apple-touch-icon"/>
# <link href="/apple-touch-icon-57x57.png" rel="apple-touch-icon" sizes="57x57"/>
# <link href="/apple-touch-icon-72x72.png" rel="apple-touch-icon" sizes="72x72"/>
# <link href="/apple-touch-icon-76x76.png" rel="apple-touch-icon" sizes="76x76"/>
# <link href="/apple-touch-icon-114x114.png" rel="apple-touch-icon" sizes="114x114"/>
# <link href="/apple-touch-icon-120x120.png" rel="apple-touch-icon" sizes="120x120"/>
# <link href="/apple-touch-icon-144x144.png" rel="apple-touch-icon" sizes="144x144"/>
# <link href="/apple-touch-icon-152x152.png" rel="apple-touch-icon" sizes="152x152"/>
# <link href="/apple-touch-icon-180x180.png" rel="apple-touch-icon" sizes="180x180"/>
# <link href="/css/main.css?version=9001.2123472247" rel="stylesheet" type="text/css"/>
# <link href="/css/jquery.nouislider.min.css" rel="stylesheet" type="text/css"/>
# <link href="/css/jquery.tags.css?version=9001.2123472247" rel="stylesheet" type="text/css"/>
# <link href="https://fonts.googleapis.com/css?family=Roboto:400,700" rel="stylesheet" type="text/css"/>
# <script src="//use.fontawesome.com/64cd5ce7ff.js"></script>
# <script src="//ajax.googleapis.com/ajax/libs/jquery/1.11.1/jquery.min.js" type="text/javascript"></script>
# <script src="/js/cookie.js?version=9001.2123472247" type="text/javascript"></script>
# <script src="//cdnjs.cloudflare.com/ajax/libs/dygraph/1.0.1/dygraph-combined.js" type="text/javascript"></script>
# <script type="application/ld+json">
#             {
#                 "@context": "http://schema.org",
#                 "@type": "WebSite",
#                 "url": "https://socialblade.com/",
#                 "potentialAction": {
#                     "@type": "SearchAction",
#                     "target": "https://socialblade.com/search/{search_term_string}",
#                     "query-input": "required name=search_term_string"
#                 }
#             }
#         </script>
# <link href="/opensearch.xml" rel="search" title="Social Blade" type="application/opensearchdescription+xml"/>
# <script>
#                     var script = document.createElement('script');
#                     var tstamp = new Date();
#                     script.id = 'factorem';
#                     script.src = '//cdm.cursecdn.com/js/socialblade/cdmfactorem_min.js?misc=' + tstamp.getTime();
#                     script.async = false;
#                     script.type = 'text/javascript';
#                     document.head.appendChild(script);
#                 </script>
# </head>
# <body style="background: #e6e9ec;">
# <div id="notification_overlay" style="position:fixed; top:0; bottom:0; left:0; right:0; background-color:#222; opacity:0.95; z-index:100001; display: none;">
#
#         </div>
# <div id="popup_overlay" style="position:fixed; top:0; bottom:0; left:0; right:0; background-color:#222; opacity:0.20; z-index:100001; display: none;">
#
#         </div>
# <div id="modal_overlay" style="position:fixed; top:0; bottom:0; left:0; right:0; background-color:#222; opacity:0.95; z-index:100001; display: none;">
#
#         </div>
# <div data-type="popup" id="dm-lightbox" style="position:fixed; top:0; bottom:0; left:0; right:0; background-color:#222; opacity:0.95; z-index:100001; display: none;">
#
#         </div>
# <div id="country-code" style="display: none;"></div>
# <script>
#   (function(i,s,o,g,r,a,m){i['GoogleAnalyticsObject']=r;i[r]=i[r]||function(){
#   (i[r].q=i[r].q||[]).push(arguments)},i[r].l=1*new Date();a=s.createElement(o),
#   m=s.getElementsByTagName(o)[0];a.async=1;a.src=g;m.parentNode.insertBefore(a,m)
#   })(window,document,'script','//www.google-analytics.com/analytics.js','ga');
#
#   ga('create', 'UA-66421947-1', 'auto', {'name': 'curseTracker'});
#   ga('create', 'UA-55884-5', 'auto', {'name' : 'socialblade'});
#
#
#   ga('socialblade.send', 'pageview');
#   ga('curseTracker.send', 'pageview');
#
#
#
# </script>
# <div id="top-header-wrap">
# <div id="top-header">
# <li class="dash-bar-menu"><a href="/forgotpw">Forgot Password?</a></li>
# <li class="dash-bar-menu"><a href="/login">Login</a></li>
# <li class="dash-bar-menu"><a href="/register">Register</a></li>
# <li class="dash-bar-menu"><a href="/authenticate"><i class="fa fa-lock"></i> Auth</a></li>
# <li class="dash-bar-menu"><a href="//support.socialblade.com" rel="nofollow" target="_blank"><i class="fa fa-ticket"></i> Contact</a></li>
# <li class="dash-bar-menu"><a href="/youtube/help" target="_blank"><i class="fa fa-question-circle"></i> FAQ</a></li>
# </div>
# </div>
# <div style="width: 100%; height: 64px; background: #2f2c2c;">
# <div id="main-menu-container" style="width: 1260px; height: 60px; margin: 0px auto; color:#fff; background: #2f2c2c;">
# <div style="width: 233px; height: 60px; margin: 0px; float: left; background: #2f2c2c; ">
# <a href="/"><img src="/images/header-logo.png?version=2" style="margin: 0px;"/></a>
# </div>
# <div style="width: 1027px; height: 60px; margin: 0px; float: left; background: #2f2c2c;">
# <form action="/twitter/search" id="topSearchForm" method="get">
# <div style="width: 340px; height: 32px; line-height: 32px; margin-top: 3px; margin-right: 2px; float: right;  background: #2f2c2c;">
# <input autofocus="autofocus" id="SearchInput" name="q" placeholder="Enter Twitter Username"/>
# <button class="search-button" type="submit" value="Search">
# <i class="fa fa-search" style="font-size: 1.1em;"></i>
# </button>
# </div>
# <div style="width: 170px; height: 32px; line-height: 32px; margin-top: 8px; float: right;">
# <select id="search-special" style="width: 155px; height: 32px; background: #555; border: 0px; color:#fff;">
# <!-- <option value="0" data-imagesrc="//socialblade.com/images/media/icons/fav-socialblade.png">All Platforms</option>-->
# <option data-imagesrc="/images/media/icons/fav-youtube.png" value="youtube">YouTube</option>
# <option data-imagesrc="/images/media/icons/fav-twitch.png" value="twitch">Twitch</option>
# <option data-imagesrc="/images/media/icons/fav-facebook.png" value="facebook">Facebook</option>
# <option data-imagesrc="/images/media/icons/fav-instagram.png" value="instagram">Instagram</option>
# <option data-imagesrc="/images/media/icons/fav-twitter.png" selected="" value="twitter">Twitter</option>
# <option data-imagesrc="/images/media/icons/fav-dailymotion.png" value="dailymotion">Dailymotion</option>
# <option data-imagesrc="/images/media/icons/fav-mixer.png" value="mixer">Mixer</option>
# </select>
# </div>
# </form>
# </div>
# </div>
# </div>
# <div id="top-menu-wrap">
# <div id="top-menu-inner-wrap">
# <div id="top-menu">
# <div class="top-menu-list"><a href="/" style="width: 25px; text-align: center;"> <i class="fa fa-home" style="color:#fff;"></i> </a></div>
# <div class="top-menu-list"><a href="//socialblade.spreadshirt.com/social-blade-shirts-C192942" style="width:25px; text-align: center;" target="_blank"> <i class="fa fa-shopping-cart" style="color:#fff; padding-right: 5px;"></i></a></div>
# <div class="top-menu-list top-menu-category-toplists">
# <span id="top-menu-platform-select" style="cursor: pointer; height: 35px; line-height: 35px; display: block; z-index: 10;">    Supported Platforms <span class="menu-cat">▼</span>   </span>
# <div id="top-menu-top-platform">
# <div id="top-menu-top-charts-inner" style="text-transform: initial;">
# <div style="width: 1050px; float: left;">
# <div id="top-menu-content-charts" style="width: 1050px; margin: 0px auto; display: block;">
# <div style="float: left; height: 30px; line-height: 30px; padding: 0px 15px; display: block; margin-right: 15px;"><a href="/youtube"><img src="/images/media/icons/fav-youtube.png" style="height: 20px; width: 20px; margin-right: 8px; margin-bottom: -5px;"/> YouTube</a></div>
# <div style="float: left; height: 30px; line-height: 30px; padding: 0px 15px; display: block; margin-right: 15px;"><a href="/twitch"><img src="/images/media/icons/fav-twitch.png" style="height: 20px; width: 20px; margin-right: 8px; margin-bottom: -5px;"/> Twitch</a></div>
# <div style="float: left; height: 30px; line-height: 30px; padding: 0px 15px; display: block; margin-right: 15px;"><a href="/twitter"><img src="/images/media/icons/fav-twitter.png" style="height: 20px; width: 20px; margin-right: 8px; margin-bottom: -5px;"/> Twitter</a></div>
# <div style="float: left; height: 30px; line-height: 30px; padding: 0px 15px; display: block; margin-right: 15px;"><a href="/instagram"><img src="/images/media/icons/fav-instagram.png" style="height: 20px; width: 20px; margin-right: 8px; margin-bottom: -5px;"/> Instagram</a></div>
# <div style="float: left; height: 30px; line-height: 30px; padding: 0px 15px; display: block; margin-right: 15px;"><a href="/facebook"><img src="/images/media/icons/fav-facebook.png" style="height: 20px; width: 20px; margin-right: 8px; margin-bottom: -5px;"/> Facebook</a></div>
# <div style="float: left; height: 30px; line-height: 30px; padding: 0px 15px; display: block; margin-right: 15px;"><a href="/dailymotion"><img src="/images/media/icons/fav-dailymotion.png" style="height: 20px; width: 20px; margin-right: 8px; margin-bottom: -5px;"/> Dailymotion</a></div>
# <div style="float: left; height: 30px; line-height: 30px; padding: 0px 15px; display: block; margin-right: 15px;"><a href="/mixer"><img src="/images/media/icons/fav-mixer.png" style="height: 20px; width: 20px; margin-right: 8px; margin-bottom: -5px;"/> Mixer</a></div>
# <div style="clear: both;"></div>
# </div>
# </div>
# <div style="clear: both;"></div></div>
# </div>
# </div>
# <div class="top-menu-list top-menu-category-toplists">
# <span id="top-menu-category-select" style="cursor: pointer; height: 35px; line-height: 35px; display: block; z-index: 10;">    Top Lists <span class="menu-cat">▼</span>   </span>
# <div id="top-menu-top-charts">
# <div id="top-menu-top-charts-inner" style="text-transform: initial;">
# <div id="top-menu-left-categories" style="width: 200px; float: left; margin-right: 50px;">
# <div class="top-menu-category-button" data-rolechange="youtube" style="cursor:pointer; background: #444; padding: 0px 10px; margin: 2px 0px; border-left: 2px solid #d64e33;">Youtube</div>
# <div class="top-menu-category-button" data-rolechange="twitch" style="cursor:pointer; background: #444; padding: 0px 10px; margin: 2px 0px; border-left: 2px solid #d64e33;">Twitch</div>
# <div class="top-menu-category-button" data-rolechange="instagram" style="cursor:pointer; background: #444; padding: 0px 10px; margin: 2px 0px; border-left: 2px solid #d64e33;">Instagram</div>
# <div class="top-menu-category-button" data-rolechange="twitter" style="cursor:pointer; background: #444; padding: 0px 10px; margin: 2px 0px; border-left: 2px solid #d64e33;">Twitter</div>
# <div class="top-menu-category-button" data-rolechange="dailymotion" style="cursor:pointer; background: #444; padding: 0px 10px; margin: 2px 0px; border-left: 2px solid #d64e33;">Dailymotion</div>
# <div class="top-menu-category-button" data-rolechange="mixer" style="cursor:pointer; background: #444; padding: 0px 10px; margin: 2px 0px; border-left: 2px solid #d64e33;">Mixer</div>
# <div class="top-menu-category-button" data-rolechange="facebook" style="cursor:pointer; background: #444; padding: 0px 10px; margin: 2px 0px; border-left: 2px solid #d64e33;">Facebook</div>
# </div>
# <div id="top-menu-left-categories" style="width: 950px; float: left;">
# <div class="top-menu-content" id="top-menu-content-youtube" style="width: 950px; float: left; display: block;">
# <div style="width: 225px; float: left;">
# <h2 class="top-menu-top-charts-header">YouTube Top Charts</h2>
# <!--<div class = "top-menu-top-charts-content"><a href = "/youtube/top/networks/mostviewed">Top 250 YouTube Networks</a></div>-->
# <div class="top-menu-top-charts-content"><a href="/youtube/top/50">Top 50 YouTubers</a></div>
# <div class="top-menu-top-charts-content"><a href="/youtube/top/100">Top 100 YouTube Channels</a></div>
# <div class="top-menu-top-charts-content"><a href="/youtube/top/500">Top 500 YouTube Channels</a></div>
# <div class="top-menu-top-charts-content" style="margin-top: 8px;"><a href="/youtube/top/trending/top-500-channels-30-days/most-subscribed">Top 500 YouTubers (30 Days)</a></div>
# <div class="top-menu-top-charts-content"><a href="/youtube/top/trending/top-500-channels-1-day/most-subscribed">Top 500 YouTubers (1 Day)</a></div>
# <div class="top-menu-top-charts-content"><a href="/youtube/top/trending/bottom-500-channels-30-days/most-unsubscribed">Worst 500 YouTubers (30 Days)</a></div>
# <div class="top-menu-top-charts-content"><a href="/youtube/top/trending/bottom-500-channels-1-day/most-unsubscribed">Worst 500 YouTubers (1 Day)</a></div>
# </div>
# <div style="width: 240px; float: left; margin-left: 30px;">
# <h2 class="top-menu-top-charts-header">YouTube Popular Countries</h2>
# <div class="top-menu-top-charts-content"><a href="/youtube/top/country/US">Top 250 from United States</a></div>
# <div class="top-menu-top-charts-content"><a href="/youtube/top/country/GB">Top 250 from United Kingdom</a></div>
# <div class="top-menu-top-charts-content"><a href="/youtube/top/country/AU">Top 250 from Australia</a></div>
# <div class="top-menu-top-charts-content"><a href="/youtube/top/country/CA">Top 250 from Canada</a></div>
# <div class="top-menu-top-charts-content"><a href="/youtube/top/country/DE">Top 250 from Germany</a></div>
# </div>
# <div style="width: 200px; float: left; margin-left: 20px;">
# <h2 class="top-menu-top-charts-header">YouTube Top Categories</h2>
# <div class="top-menu-top-charts-content"><a href="/youtube/top/category/autos">Autos &amp; Vehicles</a></div>
# <div class="top-menu-top-charts-content"><a href="/youtube/top/category/comedy">Comedy</a></div>
# <div class="top-menu-top-charts-content"><a href="/youtube/top/category/education">Education</a></div>
# <div class="top-menu-top-charts-content"><a href="/youtube/top/category/entertainment">Entertainment</a></div>
# <div class="top-menu-top-charts-content"><a href="/youtube/top/category/film">Film</a></div>
# <div class="top-menu-top-charts-content"><a href="/youtube/top/category/games">Gaming</a></div>
# <div class="top-menu-top-charts-content"><a href="/youtube/top/category/tech">Science &amp; Technology</a></div>
# <div class="top-menu-top-charts-content"><a href="/youtube/top/category/shows">Shows</a></div>
# </div>
# <div style="width: 200px; float: left;">
# <br/>
# <div class="top-menu-top-charts-content"><a href="/youtube/top/category/howto">How to &amp; Style</a></div>
# <div class="top-menu-top-charts-content"><a href="/youtube/top/category/music">Music</a></div>
# <div class="top-menu-top-charts-content"><a href="/youtube/top/category/news">News &amp; Politics</a></div>
# <div class="top-menu-top-charts-content"><a href="/youtube/top/category/nonprofit">Nonprofit &amp; Activism</a></div>
# <div class="top-menu-top-charts-content"><a href="/youtube/top/category/people">People &amp; Blogs</a></div>
# <div class="top-menu-top-charts-content"><a href="/youtube/top/category/animals">Pets &amp; Animals</a></div>
# <div class="top-menu-top-charts-content"><a href="/youtube/top/category/sports">Sports</a></div>
# <div class="top-menu-top-charts-content"><a href="/youtube/top/category/travel">Travel</a></div>
# </div>
# </div>
# <div class="top-menu-content" id="top-menu-content-twitch" style="width: 900px; float: left; display: none;">
# <div style="width: 240px; float: left;">
# <h2 class="top-menu-top-charts-header" style="color:#bf26ff;">Twitch Top Charts</h2>
# <div class="top-menu-top-charts-content"><a href="/twitch/top/10/followers">Top 10 Followed Twitch Streamers</a></div>
# <div class="top-menu-top-charts-content"><a href="/twitch/top/10/channelviews">Top 10 Viewed Twitch Streamers</a></div>
# <div class="top-menu-top-charts-content"><a href="/twitch/top/50/followers">Top 50 Followed Twitch Streamers</a></div>
# <div class="top-menu-top-charts-content"><a href="/twitch/top/50/channelviews">Top 50 Viewed Twitch Streamers</a></div>
# <div class="top-menu-top-charts-content" style="margin-top: 8px;"><a href="/twitch/top/100">Top 100 Followed Twitch Users</a></div>
# <div class="top-menu-top-charts-content"><a href="/twitch/top/100/channelviews">Top 100 Viewed Twitch Users</a></div>
# <div class="top-menu-top-charts-content"><a href="/twitch/top/500">Top 500 Followed Streamers</a></div>
# <div class="top-menu-top-charts-content"><a href="/twitch/top/500/channelviews">Top 500 Viewed Streamers</a></div>
# </div>
# </div>
# <div class="top-menu-content" id="top-menu-content-instagram" style="width: 900px; float: left; display: none;">
# <div style="width: 250px; float: left;">
# <h2 class="top-menu-top-charts-header" style="color:#2687ff;">Instagram Top Charts</h2>
# <div class="top-menu-top-charts-content"><a href="/instagram/top/50/followers">Top 50 Followed Instagram Users</a></div>
# <div class="top-menu-top-charts-content"><a href="/instagram/top/50/following">Top 50 Following Instagram Users</a></div>
# <div class="top-menu-top-charts-content"><a href="/instagram/top/50/media">Top 50 Instagram Users by Uploads</a></div>
# <div class="top-menu-top-charts-content"><a href="/instagram/top/100/followers">Top 100 Followed Instagram Users</a></div>
# <div class="top-menu-top-charts-content"><a href="/instagram/top/100/following">Top 100 Following Instagram Users</a></div>
# <div class="top-menu-top-charts-content"><a href="/instagram/top/100/media">Top 100 Instagram Users by Uploads</a></div>
# </div>
# </div>
# <div class="top-menu-content" id="top-menu-content-facebook" style="width: 900px; float: left; display: none;">
# <div style="width: 250px; float: left;">
# <h2 class="top-menu-top-charts-header" style="color:#2687ff;">Facebook Top Charts</h2>
# <div class="top-menu-top-charts-content"><a href="/facebook/top/50/likes">Top 50 Liked Facebook Pages</a></div>
# <div class="top-menu-top-charts-content"><a href="/facebook/top/100/likes">Top 100 Liked Facebook Pages</a></div>
# <div class="top-menu-top-charts-content"><a href="/facebook/top/500/likes">Top 500 Liked Facebook Pages</a></div>
# </div>
# </div>
# <div class="top-menu-content" id="top-menu-content-twitter" style="width: 900px; float: left; display: none;">
# <div style="width: 250px; float: left;">
# <h2 class="top-menu-top-charts-header" style="color:#139ed1;">Twitter Top Charts</h2>
# <div class="top-menu-top-charts-content"><a href="/twitter/top/10">Top 10 Followed Twitter Users</a></div>
# <div class="top-menu-top-charts-content"><a href="/twitter/top/10/tweets">Top 10 Twitter Users by Tweets</a></div>
# <div class="top-menu-top-charts-content"><a href="/twitter/top/10/engagements">Top 10 Twitter Users by Engagements</a></div>
# <div class="top-menu-top-charts-content"><a href="/twitter/top/50">Top 50 Followed Twitter Users</a></div>
# <div class="top-menu-top-charts-content"><a href="/twitter/top/50/tweets">Top 50 Twitter Users by Tweets</a></div>
# <div class="top-menu-top-charts-content"><a href="/twitter/top/50/engagements">Top 50 Twitter Users by Engagements</a></div>
# <div class="top-menu-top-charts-content"><a href="/twitter/top/100">Top 100 Followed Twitter Users</a></div>
# <div class="top-menu-top-charts-content"><a href="/twitter/top/100/tweets">Top 100 Twitter Users by Tweets</a></div>
# <div class="top-menu-top-charts-content"><a href="/twitter/top/100/engagements">Top 100 Twitter Users by Engagements</a></div>
# </div>
# </div>
# <div class="top-menu-content" id="top-menu-content-dailymotion" style="width: 900px; float: left; display: none;">
# <div style="width: 200px; float: left;">
# <h2 class="top-menu-top-charts-header" style="color:#1565C0;">Dailymotion Top Charts</h2>
# <div class="top-menu-top-charts-content"><a href="/dailymotion/top/50/mostfollowers">Top 50 Followed Dailymotion Users</a></div>
# <div class="top-menu-top-charts-content"><a href="/dailymotion/top/50/mostviewed">Top 50 Dailymotion Users by Views</a></div>
# <div class="top-menu-top-charts-content"><a href="/dailymotion/top/100/mostfollowers">Top 100 Followed Dailymotion Users</a></div>
# <div class="top-menu-top-charts-content"><a href="/dailymotion/top/100/mostviewed">Top 100 Dailymotion Users by Views</a></div>
# <div class="top-menu-top-charts-content"><a href="/dailymotion/top/500/mostfollowers">Top 500 Followed Dailymotion Users</a></div>
# <div class="top-menu-top-charts-content"><a href="/dailymotion/top/500/mostviewed">Top 500 Dailymotion Users by Views</a></div>
# </div>
# <div style="width: 240px; float: left; margin-left: 30px;">
# <h2 class="top-menu-top-charts-header" style="color:#1565C0;">Dailymotion Popular Countries</h2>
# <div class="top-menu-top-charts-content"><a href="/dailymotion/top/country/us">Top 250 from United States</a></div>
# <div class="top-menu-top-charts-content"><a href="/dailymotion/top/country/gb">Top 250 from United Kingdom</a></div>
# <div class="top-menu-top-charts-content"><a href="/dailymotion/top/country/au">Top 250 from Australia</a></div>
# <div class="top-menu-top-charts-content"><a href="/dailymotion/top/country/ca">Top 250 from Canada</a></div>
# <div class="top-menu-top-charts-content"><a href="/dailymotion/top/country/de">Top 250 from Germany</a></div>
# </div>
# <div style="width: 200px; float: left; margin-left: 20px;">
# <h2 class="top-menu-top-charts-header" style="color:#1565C0;">Dailymotion Categories</h2>
# <div class="top-menu-top-charts-content"><a href="/dailymotion/top/category/animals">Pets &amp; Animals</a></div>
# <div class="top-menu-top-charts-content"><a href="/dailymotion/top/category/autos">Autos &amp; Vehicles</a></div>
# <div class="top-menu-top-charts-content"><a href="/dailymotion/top/category/creation">Creative</a></div>
# <div class="top-menu-top-charts-content"><a href="/dailymotion/top/category/fun">Fun</a></div>
# <div class="top-menu-top-charts-content"><a href="/dailymotion/top/category/videogames">Games</a></div>
# <div class="top-menu-top-charts-content"><a href="/dailymotion/top/category/kids">Kids</a></div>
# <div class="top-menu-top-charts-content"><a href="/dailymotion/top/category/lifestyle">Lifestyle &amp; Entertainment</a></div>
# <div class="top-menu-top-charts-content"><a href="/dailymotion/top/category/music">Music</a></div>
# <div class="top-menu-top-charts-content"><a href="/dailymotion/top/category/news">News &amp; Politics</a></div>
# </div>
# <div style="width: 200px; float: left;">
# <br/>
# <div class="top-menu-top-charts-content"><a href="/dailymotion/top/category/people">People &amp; Blogs</a></div>
# <div class="top-menu-top-charts-content"><a href="/dailymotion/top/category/school">School &amp; Education</a></div>
# <div class="top-menu-top-charts-content"><a href="/dailymotion/top/category/sexy">Sexy &amp; Mature</a></div>
# <div class="top-menu-top-charts-content"><a href="/dailymotion/top/category/sports">Sports</a></div>
# <div class="top-menu-top-charts-content"><a href="/dailymotion/top/category/tech">Technology</a></div>
# <div class="top-menu-top-charts-content"><a href="/dailymotion/top/category/travel">Travel</a></div>
# <div class="top-menu-top-charts-content"><a href="/dailymotion/top/category/tv">Television &amp; Shows</a></div>
# <div class="top-menu-top-charts-content"><a href="/dailymotion/top/category/webcam">Webcam &amp; Vlogs</a></div>
# </div>
# </div>
# <div class="top-menu-content" id="top-menu-content-mixer" style="width: 900px; float: left; display: none;">
# <div style="width: 250px; float: left;">
# <h2 class="top-menu-top-charts-header" style="color:#4FC3F7;">Mixer Top Charts</h2>
# <div class="top-menu-top-charts-content"><a href="/mixer/top/50/most-followers">Top 50 Most Followed Mixer Streamers</a></div>
# <div class="top-menu-top-charts-content"><a href="/mixer/top/50/most-viewed">Top 50 Mixer Streamers by Total Views</a></div>
# <div class="top-menu-top-charts-content"><a href="/mixer/top/50/highest-level">Top 50 Mixer Streamers by Highest Level</a></div>
# <div class="top-menu-top-charts-content"><a href="/mixer/top/100/most-followers">Top 100 Most Followed Mixer Streamers</a></div>
# <div class="top-menu-top-charts-content"><a href="/mixer/top/100/most-viewed">Top 100 Mixer Streamers by Total Views</a></div>
# <div class="top-menu-top-charts-content"><a href="/mixer/top/100/highest-level">Top 100 Mixer Streamers by Highest Level</a></div>
# <div class="top-menu-top-charts-content"><a href="/mixer/top/500/most-followers">Top 500 Most Followed Mixer Streamers</a></div>
# <div class="top-menu-top-charts-content"><a href="/mixer/top/500/most-viewed">Top 500 Mixer Streamers by Total Views</a></div>
# <div class="top-menu-top-charts-content"><a href="/mixer/top/500/highest-level">Top 500 Mixer Streamers by Highest Level</a></div>
# </div>
# </div>
# </div>
# <div style="clear: both;"></div></div>
# </div>
# </div>
# <div class="top-menu-list top-menu-category-toplists">
# <span id="top-menu-realtime-select" style="cursor: pointer; height: 35px; line-height: 35px; display: block; z-index: 10;">    Live Counts / Realtime <span class="menu-cat">▼</span>   </span>
# <div id="top-menu-top-realtime">
# <div id="top-menu-top-realtime-inner" style="text-transform: initial;">
# <div style="width: 1220px; float: left;">
# <div id="top-menu-content-realtime" style="width: 1220px; float: left; display: block; font-size: 0.9em;">
# <div style="width: 225px; float: left;">
# <h2 class="top-menu-top-realtime-header">YouTube Realtime</h2>
# <a href="/youtube/realtime">YouTube Live Sub Count</a>
# </div>
# <div style="width: 225px; float: left; margin-left: 20px;">
# <h2 class="top-menu-top-realtime-header">Twitch Realtime</h2>
# <a href="/twitch/realtime">Twitch Live Follower Count</a>
# </div>
# <div style="width: 225px; float: left;">
# <h2 class="top-menu-top-realtime-header">Twitter Realtime</h2>
# <a href="/twitter/realtime">Twitter Live Follower Count</a>
# </div>
# <div style="width: 225px; float: left;">
# <h2 class="top-menu-top-realtime-header">Dailymotion Realtime</h2>
# <a href="/dailymotion/realtime">Dailymotion Live Follower Count</a>
# </div>
# <div style="width: 225px; float: left;">
# <h2 class="top-menu-top-realtime-header">Mixer Realtime</h2>
# <a href="/mixer/realtime">Mixer Live Follower Count</a>
# </div>
# </div>
# </div>
# <div style="clear: both;"></div></div>
# </div>
# </div>
# <div class="top-menu-list"><a href="/grow-and-brand-your-youtube-channel">Consulting</a></div>
# <div class="top-menu-list"><a href="/compare">Compare</a></div>
# <div class="top-menu-list"><a href="https://socialblade.com/blog/">Blog</a></div>
# </div>
# <div id="top-menu-social">
# <div class="top-menu-partner" style="width: 260px; background: #d63e33; text-align: center;"><a class="top-partner-link" href="https://socialblade.com/discord/" style="color:#ffffff;">Community Discord</a></div>
# </div>
# </div>
# </div>
# <br/>
# <div class="section-container-no-margin">
# <div style="section-full-width">
# <div class="section-panel">
# <form action="/twitter/search/" autocomplete="off" method="GET">
# <img alt="Twitter Logo" class="section-search-icon" src="/images/media/icons/fav-twitter.png"/>
# <input class="section-search-box" name="q" placeholder="Type a Twitter username to look up their stats." type="text"/>
# <input class="section-search-btn" type="submit" value="Search for User"/>
# </form>
# </div>
# </div>
# <div class="clear-both"></div>
# </div>
# <div class="section-container-margin">
# <div class="section-leftside">
# <div class="section-square-vert"> <div style="width: 298px; height: 248px; margin: 0px auto 11px auto;">
# <div style="z-index:10; position:absolute;">
# <div id="cdm-zone-02"></div> </div>
# <div class="socialblade-heartbeat" style="z-index:5; position:absolute; display: none;">
# <div style="width: 297px; height: 247px; background: #d37a74; border: 2px solid #b3382c; text-align: center;">
# <i class="fa fa-exclamation-triangle fa-5x" style="margin-top: 20px; color:#fff;"></i>
# <div style="margin: 0px auto; width: 80%; color:#fff; margin-top: 10px; font-size: 10pt; line-height: 1.5em;">Hello, visitor! Please consider adding SocialBlade.com to your adblock whitelist. Our ads support the development and upkeep of the site. Upgrade to a <a href="/products/subscription" style="color:#fff;">Premium Subscription</a> to load the site without ads.
# 				</div>
# </div><div style="clear: both;"></div>
# </div>
# </div>
# </div>
# </div>
# <div class="section-rightside">
# <div class="section-panel">
# <h1>Social Blade Twitter Stats</h1>
# <h5><a href="/">home</a> / twitter</h5>
# </div>
# <div class="section-panel-header section-margin-top">
# <h2>Social Blade Twitter Team (Community Leaders)</h2>
# </div>
# <div class="section-panel-small">
# <a href="/twitter/user/sonicorbstudios"><img alt="SonicOrbStudios's Twitter Stats'" class="section-community-leaders" src="https://pbs.twimg.com/profile_images/797258999481663488/td6l5xuA.jpg"/></a>
# <a href="/twitter/user/kestalkayden"><img alt="KestalKayden's Twitter Stats'" class="section-community-leaders" src="https://pbs.twimg.com/profile_images/925542087550013440/ILDQpCLX.jpg"/></a>
# <a href="/twitter/user/urgo"><img alt="Urgo's Twitter Stats'" class="section-community-leaders" src="https://pbs.twimg.com/profile_images/526045994111098880/w-iK2OjV.jpeg"/></a>
# <a href="/twitter/user/greengully"><img alt="GreenGully's Twitter Stats'" class="section-community-leaders" src="https://pbs.twimg.com/profile_images/875244997930504192/omi8njVq.jpg"/></a>
# <a href="/twitter/user/modesttim"><img alt="ModestTim's Twitter Stats'" class="section-community-leaders" src="https://pbs.twimg.com/profile_images/840498186812850177/EldBFGgr.jpg"/></a>
# </div>
# </div>
# <div class="clear-both"></div>
# </div>
# <div class="section-container-no-margin">
# <div class="section-full-width">
# <div class="section-panel-header">
# <h2>Top 25 Twitter Users by Followers <a href="/twitter/top/100/followers">View More</a></h2>
# </div>
# <div class="table-header section-rank">Rank</div>
# <div class="table-header section-grade">Grade</div>
# <div class="table-header section-med">Username</div>
# <div class="table-header section-lg">Display Name</div>
# <div class="table-header section-sm">Tweets</div>
# <div class="table-header section-med">Followers</div>
# <div class="table-header section-med">Following</div>
# <div class="clear-both"></div>
# <div class="table-body">
# <div class="table-cell section-rank">1</div>
# <div class="table-cell section-grade"><span style="color:#00bee7;">A++</span></div>
# <div class="table-cell section-med"><a href="/twitter/user/katyperry">katyperry</a></div>
# <div class="table-cell section-lg">KATY PERRY</div>
# <div class="table-cell section-sm">10,002</div>
# <div class="table-cell section-med">107,628,466</div>
# <div class="table-cell section-med">220</div>
# </div>
# <div class="table-body">
# <div class="table-cell section-rank">2</div>
# <div class="table-cell section-grade"><span style="color:#00bee7;">A++</span></div>
# <div class="table-cell section-med"><a href="/twitter/user/barackobama">BarackObama</a></div>
# <div class="table-cell section-lg">Barack Obama</div>
# <div class="table-cell section-sm">15,645</div>
# <div class="table-cell section-med">106,838,347</div>
# <div class="table-cell section-med">613,544</div>
# </div>
# <div class="table-body">
# <div class="table-cell section-rank">3</div>
# <div class="table-cell section-grade"><span style="color:#00bee7;">A++</span></div>
# <div class="table-cell section-med"><a href="/twitter/user/justinbieber">justinbieber</a></div>
# <div class="table-cell section-lg">Justin Bieber</div>
# <div class="table-cell section-sm">30,491</div>
# <div class="table-cell section-med">105,898,645</div>
# <div class="table-cell section-med">298,264</div>
# </div>
# <div class="table-body">
# <div class="table-cell section-rank">4</div>
# <div class="table-cell section-grade"><span style="color:#00bee7;">A++</span></div>
# <div class="table-cell section-med"><a href="/twitter/user/rihanna">rihanna</a></div>
# <div class="table-cell section-lg">Rihanna</div>
# <div class="table-cell section-sm">10,320</div>
# <div class="table-cell section-med">91,833,267</div>
# <div class="table-cell section-med">1,081</div>
# </div>
# <div class="table-body">
# <div class="table-cell section-rank">5</div>
# <div class="table-cell section-grade"><span style="color:#00bee7;">A++</span></div>
# <div class="table-cell section-med"><a href="/twitter/user/taylorswift13">taylorswift13</a></div>
# <div class="table-cell section-lg">Taylor Swift</div>
# <div class="table-cell section-sm">217</div>
# <div class="table-cell section-med">83,703,185</div>
# <div class="table-cell section-med">0</div>
# </div>
# <div class="table-body">
# <div class="table-cell section-rank">6</div>
# <div class="table-cell section-grade"><span style="color:#00bee7;">A++</span></div>
# <div class="table-cell section-med"><a href="/twitter/user/ladygaga">ladygaga</a></div>
# <div class="table-cell section-lg">Lady Gaga</div>
# <div class="table-cell section-sm">8,964</div>
# <div class="table-cell section-med">78,812,787</div>
# <div class="table-cell section-med">124,883</div>
# </div>
# <div class="table-body">
# <div class="table-cell section-rank">7</div>
# <div class="table-cell section-grade"><span style="color:#00bee7;">A++</span></div>
# <div class="table-cell section-med"><a href="/twitter/user/cristiano">Cristiano</a></div>
# <div class="table-cell section-lg">Cristiano Ronaldo</div>
# <div class="table-cell section-sm">3,411</div>
# <div class="table-cell section-med">78,527,212</div>
# <div class="table-cell section-med">51</div>
# </div>
# <div class="table-body">
# <div class="table-cell section-rank">8</div>
# <div class="table-cell section-grade"><span style="color:#00bee7;">A++</span></div>
# <div class="table-cell section-med"><a href="/twitter/user/theellenshow">TheEllenShow</a></div>
# <div class="table-cell section-lg">Ellen DeGeneres</div>
# <div class="table-cell section-sm">19,799</div>
# <div class="table-cell section-med">77,962,296</div>
# <div class="table-cell section-med">31,238</div>
# </div>
# <div class="table-body">
# <div class="table-cell section-rank">9</div>
# <div class="table-cell section-grade"><span style="color:#00bee7;">A++</span></div>
# <div class="table-cell section-med"><a href="/twitter/user/youtube">YouTube</a></div>
# <div class="table-cell section-lg">YouTube</div>
# <div class="table-cell section-sm">23,494</div>
# <div class="table-cell section-med">71,592,617</div>
# <div class="table-cell section-med">1,036</div>
# </div>
# <div class="table-body">
# <div class="table-cell section-rank">10</div>
# <div class="table-cell section-grade"><span style="color:#00bee7;">A++</span></div>
# <div class="table-cell section-med"><a href="/twitter/user/jtimberlake">jtimberlake</a></div>
# <div class="table-cell section-lg">Justin Timberlake</div>
# <div class="table-cell section-sm">4,095</div>
# <div class="table-cell section-med">65,000,525</div>
# <div class="table-cell section-med">291</div>
# </div>
# <div class="table-body">
# <div class="table-cell section-rank">11</div>
# <div class="table-cell section-grade"><span style="color:#00bee7;">A++</span></div>
# <div class="table-cell section-med"><a href="/twitter/user/arianagrande">ArianaGrande</a></div>
# <div class="table-cell section-lg">Ariana Grande</div>
# <div class="table-cell section-sm">44,634</div>
# <div class="table-cell section-med">63,670,733</div>
# <div class="table-cell section-med">61,932</div>
# </div>
# <div class="table-body">
# <div class="table-cell section-rank">12</div>
# <div class="table-cell section-grade"><span style="color:#00bee7;">A++</span></div>
# <div class="table-cell section-med"><a href="/twitter/user/realdonaldtrump">realDonaldTrump</a></div>
# <div class="table-cell section-lg">Donald J. Trump</div>
# <div class="table-cell section-sm">42,602</div>
# <div class="table-cell section-med">61,581,442</div>
# <div class="table-cell section-med">47</div>
# </div>
# <div class="table-body">
# <div class="table-cell section-rank">13</div>
# <div class="table-cell section-grade"><span style="color:#00bee7;">A++</span></div>
# <div class="table-cell section-med"><a href="/twitter/user/kimkardashian">KimKardashian</a></div>
# <div class="table-cell section-lg">Kim Kardashian West</div>
# <div class="table-cell section-sm">29,629</div>
# <div class="table-cell section-med">61,137,442</div>
# <div class="table-cell section-med">146</div>
# </div>
# <div class="table-body">
# <div class="table-cell section-rank">14</div>
# <div class="table-cell section-grade"><span style="color:#00bee7;">A++</span></div>
# <div class="table-cell section-med"><a href="/twitter/user/selenagomez">selenagomez</a></div>
# <div class="table-cell section-lg">Selena Gomez</div>
# <div class="table-cell section-sm">4,385</div>
# <div class="table-cell section-med">57,814,832</div>
# <div class="table-cell section-med">1,188</div>
# </div>
# <div class="table-body">
# <div class="table-cell section-rank">15</div>
# <div class="table-cell section-grade"><span style="color:#00bee7;">A++</span></div>
# <div class="table-cell section-med"><a href="/twitter/user/ddlovato">ddlovato</a></div>
# <div class="table-cell section-lg">Demi Lovato</div>
# <div class="table-cell section-sm">17,080</div>
# <div class="table-cell section-med">57,439,469</div>
# <div class="table-cell section-med">535</div>
# </div>
# <div class="table-body">
# <div class="table-cell section-rank">16</div>
# <div class="table-cell section-grade"><span style="color:#00bee7;">A++</span></div>
# <div class="table-cell section-med"><a href="/twitter/user/britneyspears">britneyspears</a></div>
# <div class="table-cell section-lg">Britney Spears</div>
# <div class="table-cell section-sm">5,628</div>
# <div class="table-cell section-med">56,372,738</div>
# <div class="table-cell section-med">381,863</div>
# </div>
# <div class="table-body">
# <div class="table-cell section-rank">17</div>
# <div class="table-cell section-grade"><span style="color:#69ce10;">A+</span></div>
# <div class="table-cell section-med"><a href="/twitter/user/twitter">Twitter</a></div>
# <div class="table-cell section-lg">Twitter</div>
# <div class="table-cell section-sm">10,677</div>
# <div class="table-cell section-med">56,254,842</div>
# <div class="table-cell section-med">140</div>
# </div>
# <div class="table-body">
# <div class="table-cell section-rank">18</div>
# <div class="table-cell section-grade"><span style="color:#69ce10;">A+</span></div>
# <div class="table-cell section-med"><a href="/twitter/user/cnnbrk">cnnbrk</a></div>
# <div class="table-cell section-lg">CNN Breaking News</div>
# <div class="table-cell section-sm">66,574</div>
# <div class="table-cell section-med">55,402,266</div>
# <div class="table-cell section-med">121</div>
# </div>
# <div class="table-body">
# <div class="table-cell section-rank">19</div>
# <div class="table-cell section-grade"><span style="color:#69ce10;">A+</span></div>
# <div class="table-cell section-med"><a href="/twitter/user/shakira">shakira</a></div>
# <div class="table-cell section-lg">Shakira</div>
# <div class="table-cell section-sm">6,237</div>
# <div class="table-cell section-med">51,292,424</div>
# <div class="table-cell section-med">209</div>
# </div>
# <div class="table-body">
# <div class="table-cell section-rank">20</div>
# <div class="table-cell section-grade"><span style="color:#69ce10;">A+</span></div>
# <div class="table-cell section-med"><a href="/twitter/user/jimmyfallon">jimmyfallon</a></div>
# <div class="table-cell section-lg">jimmy fallon</div>
# <div class="table-cell section-sm">11,978</div>
# <div class="table-cell section-med">51,236,102</div>
# <div class="table-cell section-med">8,929</div>
# </div>
# <div class="table-body">
# <div class="table-cell section-rank">21</div>
# <div class="table-cell section-grade"><span style="color:#69ce10;">A+</span></div>
# <div class="table-cell section-med"><a href="/twitter/user/narendramodi">narendramodi</a></div>
# <div class="table-cell section-lg">Narendra Modi</div>
# <div class="table-cell section-sm">24,009</div>
# <div class="table-cell section-med">48,330,580</div>
# <div class="table-cell section-med">2,171</div>
# </div>
# <div class="table-body">
# <div class="table-cell section-rank">22</div>
# <div class="table-cell section-grade"><span style="color:#69ce10;">A+</span></div>
# <div class="table-cell section-med"><a href="/twitter/user/billgates">BillGates</a></div>
# <div class="table-cell section-lg">Bill Gates</div>
# <div class="table-cell section-sm">3,112</div>
# <div class="table-cell section-med">47,517,921</div>
# <div class="table-cell section-med">198</div>
# </div>
# <div class="table-body">
# <div class="table-cell section-rank">23</div>
# <div class="table-cell section-grade"><span style="color:#69ce10;">A+</span></div>
# <div class="table-cell section-med"><a href="/twitter/user/neymarjr">neymarjr</a></div>
# <div class="table-cell section-lg">Neymar Jr</div>
# <div class="table-cell section-sm">41,519</div>
# <div class="table-cell section-med">43,701,606</div>
# <div class="table-cell section-med">750</div>
# </div>
# <div class="table-body">
# <div class="table-cell section-rank">24</div>
# <div class="table-cell section-grade"><span style="color:#69ce10;">A+</span></div>
# <div class="table-cell section-med"><a href="/twitter/user/jlo">JLo</a></div>
# <div class="table-cell section-lg">Jennifer Lopez</div>
# <div class="table-cell section-sm">14,735</div>
# <div class="table-cell section-med">43,680,672</div>
# <div class="table-cell section-med">1,686</div>
# </div>
# <div class="table-body">
# <div class="table-cell section-rank">25</div>
# <div class="table-cell section-grade"><span style="color:#69ce10;">A+</span></div>
# <div class="table-cell section-med"><a href="/twitter/user/nytimes">nytimes</a></div>
# <div class="table-cell section-lg">The New York Times</div>
# <div class="table-cell section-sm">363,899</div>
# <div class="table-cell section-med">43,644,397</div>
# <div class="table-cell section-med">898</div>
# </div>
# </div>
# <div class="clear-both"></div>
# </div>
# <div class="section-container-margin">
# <div class="section-leftside">
# <div class="section-square-vert"> <div style="width: 299px; height: 250px; margin: 1px auto 9px auto;">
# <div style="z-index:10; position:absolute;">
# <div id="cdm-zone-03"></div> </div>
# <div class="socialblade-heartbeat" style="z-index:5; position:absolute; display: none;">
# <div style="width: 297px; height: 247px; background: #d37a74; border: 2px solid #b3382c; text-align: center;">
# <i class="fa fa-exclamation-triangle fa-5x" style="margin-top: 20px; color:#fff;"></i>
# <div style="margin: 0px auto; width: 80%; color:#fff; margin-top: 10px; font-size: 10pt; line-height: 1.5em;">Hello, visitor! Please consider adding SocialBlade.com to your adblock whitelist. Our ads support the development and upkeep of the site. Upgrade to a <a href="/products/subscription" style="color:#fff;">Premium Subscription</a> to load the site without ads.
# 				</div>
# </div><div style="clear: both;"></div>
# </div>
# </div>
# </div>
# </div>
# <div class="section-rightside">
# <div class="section-panel-header">
# <h2>Random Community Members</h2>
# </div>
# <div class="section-panel-small">
# <a href="/twitter/user/cerso93"><img alt="Cerso93's Twitter Stats'" class="section-community-members" src="https://pbs.twimg.com/profile_images/1074440863693070336/bXP5KIhy.jpg" style="width: 88px; height: 88px;"/></a>
# <a href="/twitter/user/itspureskin"><img alt="ItsPureSkin's Twitter Stats'" class="section-community-members" src="https://pbs.twimg.com/profile_images/1115754169011527680/qIXHF9ds.jpg" style="width: 88px; height: 88px;"/></a>
# <a href="/twitter/user/starlingvibes"><img alt="Starlingvibes's Twitter Stats'" class="section-community-members" src="http://pbs.twimg.com/profile_images/1020661372198277121/nir9dmrV.jpg" style="width: 88px; height: 88px;"/></a>
# <a href="/twitter/user/arethebs"><img alt="AreTheBS's Twitter Stats'" class="section-community-members" src="https://pbs.twimg.com/profile_images/1113708747237597184/viRlZw8v.jpg" style="width: 88px; height: 88px;"/></a>
# <a href="/twitter/user/akosironhenley"><img alt="akosironhenley's Twitter Stats'" class="section-community-members" src="https://pbs.twimg.com/profile_images/1119847770158845952/cvN4F7L0.jpg" style="width: 88px; height: 88px;"/></a>
# <a href="/twitter/user/gankstars"><img alt="gankstars's Twitter Stats'" class="section-community-members" src="https://pbs.twimg.com/profile_images/1135640633673039872/Mc9tGlh1.jpg" style="width: 88px; height: 88px;"/></a>
# <a href="/twitter/user/antoni0tornetta"><img alt="Antoni0tornetta's Twitter Stats'" class="section-community-members" src="https://pbs.twimg.com/profile_images/1126727432768110592/EQtuzakC.jpg" style="width: 88px; height: 88px;"/></a>
# <a href="/twitter/user/wickedshrapnel"><img alt="wickedshrapnel's Twitter Stats'" class="section-community-members" src="https://pbs.twimg.com/profile_images/1142190373391020032/UBvJExiy.jpg" style="width: 88px; height: 88px;"/></a>
# <a href="/twitter/user/astroneergame"><img alt="astroneergame's Twitter Stats'" class="section-community-members" src="https://pbs.twimg.com/profile_images/1136049142700994560/TN5NsYFP.png" style="width: 88px; height: 88px;"/></a>
# <a href="/twitter/user/connorsparkyy"><img alt="ConnorSparkyy's Twitter Stats'" class="section-community-members" src="https://pbs.twimg.com/profile_images/1134238658540838913/le_jp0wQ.jpg" style="width: 88px; height: 88px;"/></a>
# <a href="/twitter/user/antgrasso"><img alt="antgrasso's Twitter Stats'" class="section-community-members" src="https://pbs.twimg.com/profile_images/1121360169319981058/1W13Y7Vi.png" style="width: 88px; height: 88px;"/></a>
# <a href="/twitter/user/legavolleyfem"><img alt="LegaVolleyFem's Twitter Stats'" class="section-community-members" src="https://pbs.twimg.com/profile_images/876714048825548800/ZNlrI_yV.jpg" style="width: 88px; height: 88px;"/></a>
# <a href="/twitter/user/killadeiphia"><img alt="KilladeIphia's Twitter Stats'" class="section-community-members" src="https://pbs.twimg.com/profile_images/1140391223385100291/k5Q8Xi2_.jpg" style="width: 88px; height: 88px;"/></a>
# <a href="/twitter/user/starlingvibe"><img alt="Starlingvibe's Twitter Stats'" class="section-community-members" src="http://pbs.twimg.com/profile_images/1056331944919744512/Q-22lQWh.jpg" style="width: 88px; height: 88px;"/></a>
# <a href="/twitter/user/rizalmuk"><img alt="rizalmuk's Twitter Stats'" class="section-community-members" src="https://pbs.twimg.com/profile_images/947640889249107968/b6BOLT88.jpg" style="width: 88px; height: 88px;"/></a>
# <a href="/twitter/user/sacramentotmt"><img alt="SacramentoTMT's Twitter Stats'" class="section-community-members" src="https://pbs.twimg.com/profile_images/1131622181098676224/Vvi1FwTb.png" style="width: 88px; height: 88px;"/></a>
# <a href="/twitter/user/theybelikedar"><img alt="TheybelikeDar's Twitter Stats'" class="section-community-members" src="http://pbs.twimg.com/profile_images/958745615986581505/yacGOn-_.jpg" style="width: 88px; height: 88px;"/></a>
# <a href="/twitter/user/fangoria"><img alt="FANGORIA's Twitter Stats'" class="section-community-members" src="https://pbs.twimg.com/profile_images/1137017108628459520/XlKeI5Ao.png" style="width: 88px; height: 88px;"/></a>
# </div>
# <div class="section-long-vert-container">
# <div class="section-long-vert">
# <div style="width: 727px; height: 91px; margin: 0px auto 9px auto;">
# <div style="z-index:10; position:absolute;">
# <div id="cdm-zone-01"></div> </div>
# <div class="socialblade-heartbeat" style="z-index:5; position:absolute; display: none;">
# <div style="width: 726px; height: 87px; background: #d37a74; border: 2px solid #b3382c;">
# <i class="fa fa-exclamation-triangle fa-5x" style="margin: 12px 30px; width: 60px; color: #fff; float: left;"></i>
# <div style="margin: 0px auto; width: 90%; color:#fff; margin-top: 15px; font-size: 10pt; line-height: 1.5em;">Hello, visitor! Please consider adding SocialBlade.com to your adblock whitelist. Our ads support the development and upkeep of the site. Upgrade to a <a href="/products/subscription" style="color:#fff;">Premium Subscription</a> to load the site without ads.
# 				</div>
# </div><div style="clear: both;"></div>
# </div>
# </div>
# </div>
# <div class="clear-both"></div>
# </div>
# </div>
# <div class="clear-both"></div>
# </div>
# <!-- Start Quantcast tag -->
# <script src="//edge.quantserve.com/quant.js" type="text/javascript"></script>
# <script type="text/javascript">_qacct="p-faFRxScvpTI4c";quantserve();</script>
# <noscript>
# <a href="//www.quantcast.com/p-faFRxScvpTI4c" target="_blank"><img alt="Quantcast" height="1" src="//pixel.quantserve.com/pixel/p-faFRxScvpTI4c.gif" style="display: none; border: 0px;" width="1"/></a>
# </noscript>
# <!-- End Quantcast tag -->
# <!-- Start Alexa Certify Javascript -->
# <script src="https://d31qbv1cthcecs.cloudfront.net/atrk.js" type="text/javascript"></script><script type="text/javascript">_atrk_opts = { atrk_acct: "wV67f1awO400Wn", domain:"socialblade.com"}; atrk ();</script><noscript><img alt="" height="1" src="https://d5nxst8fruw4z.cloudfront.net/atrk.gif?account=wV67f1awO400Wn" style="display:none" width="1"/></noscript>
# <!-- End Alexa Certify Javascript -->
# <!-- Start of Chart Beat -->
# <script type="text/javascript">
# var _sf_async_config={uid:25253,domain:"socialblade.com"};
# (function(){
#   function loadChartbeat() {
#     window._sf_endpt=(new Date()).getTime();
#     var e = document.createElement('script');
#     e.setAttribute('language', 'javascript');
#     e.setAttribute('type', 'text/javascript');
#     e.setAttribute('src',
#        (("https:" == document.location.protocol) ? "https://a248.e.akamai.net/chartbeat.download.akamai.com/102508/" : "http://static.chartbeat.com/") +
#        "js/chartbeat.js");
#     document.body.appendChild(e);
#   }
#   var oldonload = window.onload;
#   window.onload = (typeof window.onload != 'function') ?
#      loadChartbeat : function() { oldonload(); loadChartbeat(); };
# })();
# </script>
# <!-- Begin comScore -->
# <script>
# var _comscore = _comscore || [];
# _comscore.push({ c1: "2", c2: "6035118" });
# (function() {
#    var s = document.createElement("script"), el = document.getElementsByTagName("script")[0]; s.async = true;
#    s.src = (document.location.protocol == "https:" ? "https://sb" : "http://b") + ".scorecardresearch.com/beacon.js";
#    el.parentNode.insertBefore(s, el);
# })();
# </script>
# <noscript>
# <img src="http://b.scorecardresearch.com/p?c1=2&amp;c2=6035118&amp;cv=2.0&amp;cj=1"/>
# </noscript>
# <!-- End comScore -->
# <!-- Nielsen Online SiteCensus -->
# <script type="text/javascript">
# (function () {
#    var d = new Image(1, 1);
#    d.onerror = d.onload = function () {
#        d.onerror = d.onload = null;
#    };
#    d.src = ["//secure-us.imrworldwide.com/cgi-bin/m?ci=us-603339h&cg=0&cc=1&si=", escape(window.location.href), "&rp=", escape(document.referrer), "&ts=compact&rnd=", (new Date()).getTime()].join('');
# })();
# </script>
# <noscript>
#    &lt;div&gt;&lt;img src="//secure-us.imrworldwide.com/cgi-bin/m?ci=us-603339h&amp;amp;cg=0&amp;amp;cc=1&amp;amp;ts=noscript" width="1" height="1" alt="" /&gt;&lt;/div&gt;
# </noscript>
# <!-- End Nielsen Online SiteCensus -->
# <script async="" src="//sia.socialblade.com/cb/cb.php?r="></script>
# <!-- Facebook Pixel Code -->
# <script>
# !function(f,b,e,v,n,t,s){if(f.fbq)return;n=f.fbq=function(){n.callMethod?
# n.callMethod.apply(n,arguments):n.queue.push(arguments)};if(!f._fbq)f._fbq=n;
# n.push=n;n.loaded=!0;n.version='2.0';n.queue=[];t=b.createElement(e);t.async=!0;
# t.src=v;s=b.getElementsByTagName(e)[0];s.parentNode.insertBefore(t,s)}(window,
# document,'script','//connect.facebook.net/en_US/fbevents.js');
#
# fbq('init', '490438394442284');
# fbq('track', "PageView");</script>
# <noscript><img height="1" src="https://www.facebook.com/tr?id=490438394442284&amp;ev=PageView&amp;noscript=1" style="display:none" width="1"/></noscript>
# <!-- End Facebook Pixel Code -->
# <div id="bottomAd">
#
# </div>
# <div id="footer-bar-wrap">
# <div>
# <span class="float-left">Main Mobile App:   </span>
# <a href="https://play.google.com/store/apps/details?id=com.socialblade.droid.statistics" target="_blank"><img src="/images/mobile/google-play-store.png" style="margin-right: 5px;"/></a>
# <a href="https://itunes.apple.com/ca/app/social-blade-statistics-app/id838333283?mt=8" target="_blank"><img src="/images/mobile/apple-store.png"/></a>
# <span class="float-left" style="margin-left: 40px;">Browser Extensions:   </span>
# <a href="https://chrome.google.com/webstore/detail/social-blade/cfidkbgamfhdgmedldkagjopnbobdmdn" target="_blank"><img src="/images/mobile/chrome-extensions.png"/></a>
# <a href="https://addon.socialblade.com/"><img src="/images/mobile/firefox-extensions.png"/></a>
# <span class="float-left" style="margin-left: 40px;">Real Time App:   </span>
# <a href="https://play.google.com/store/apps/details?id=com.socialblade.droid.realtime" target="_blank"><img src="/images/mobile/google-play-store.png" style="margin-right: 5px;"/></a>
# <a href="https://itunes.apple.com/ca/app/live-sub-count-social-blade/id1208869005?mt=8" target="_blank"><img src="/images/mobile/apple-store.png"/></a>
# <a class="core-button core-wide ui-green float-right" href="//support.socialblade.com" target="_blank">   Contact Social Blade Support   </a><br/>
# </div>
# </div>
# <div id="footer-main-outer-wrap">
# <div id="footer-main-inner-wrap">
# <div id="footer-section-wrap">
# <div id="footer-section-1">
# <a class="footer-social-block" href="https://youtube.com/user/socialblade" rel="nofollow" target="_blank">
# <div style="background: #b31217; margin-right: 10px;">
# <i class="fa fa-youtube-play"></i>
# </div>
# </a>
# <a class="footer-social-block" href="https://facebook.com/social.blade" rel="nofollow" target="_blank">
# <div style="background: #3b5998; margin-right: 10px;">
# <i class="fa fa-facebook"></i>
# </div>
# </a>
# <a class="footer-social-block" href="https://twitter.com/socialblade" rel="nofollow" target="_blank">
# <div style="background: #55acee; margin-right: 10px;">
# <i class="fa fa-twitter"></i>
# </div>
# </a>
# <a class="footer-social-block" href="https://instagram.com/socialblade" rel="nofollow" target="_blank">
# <div style="background: #c08d64; margin-right: 10px;">
# <i class="fa fa-instagram"></i>
# </div>
# </a>
# <a class="footer-social-block" href="https://plus.google.com/+socialblade" rel="nofollow" target="_blank">
# <div style="background: #d34836;">
# <i class="fa fa-google-plus" style="font-size: 1.3em; margin-left: 2px; margin-top: 8px;"></i>
# </div>
# </a>
# <div class="clear-both next-line"></div>
# <h3 class="footer-header">More Social Blade</h3>
# <div>
# <a class="footer-link" href="/blog/" target="_blank">Social Blade Blog</a>
# <!-- <a target = "_blank" href = "//forums.socialblade.com/forum.php" class = "footer-link">Community Forum</a> -->
# <a class="footer-link" href="/tools/" target="_blank">Social Blade Tools</a>
# <a class="footer-link" href="/dashboard" target="_blank">Social Blade Dashboard</a>
# <a class="footer-link" href="/youtube/education" target="_blank">YouTube EDU</a>
# <a class="footer-link" href="/grow-and-brand-your-youtube-channel" target="_blank">YouTube Consulting</a>
# <a class="footer-link" href="/youtube/youtube-money-calculator" target="_blank">YouTube Money Calculator / Estimated Earnings</a>
# </div>
# </div>
# <div style="width: 260px; float: left; margin-right: 20px;">
# <h3 class="footer-header">Integrated Platforms</h3>
# <div>
# <a class="footer-link" href="/youtube/">YouTube</a>
# <a class="footer-link" href="/twitch">Twitch</a>
# <a class="footer-link" href="/twitter">Twitter</a>
# <a class="footer-link" href="/instagram">Instagram</a>
# <a class="footer-link" href="/dailymotion">Dailymotion</a>
# </div>
# <h3 class="footer-header" style="margin-top: 16px;">Social Media</h3>
# <div>
# <a class="footer-link" href="//youtube.com/socialblade" rel="nofollow" target="_blank">YouTube</a>
# <a class="footer-link" href="//twitter.com/socialblade" rel="nofollow" target="_blank">Twitter</a>
# <a class="footer-link" href="//facebook.com/socialblade" rel="nofollow" target="_blank">Facebook</a>
# <a class="footer-link" href="//twitch.tv/socialbladegaming" rel="nofollow" target="_blank">Twitch</a>
# <a class="footer-link" href="//plus.google.com/+socialblade" rel="nofollow" target="_blank">Google+</a>
# </div>
# </div>
# <div style="width: 330px; float: left;">
# <h3 class="footer-header">We're YouTube Certified!</h3>
# <div>
# <a class="footer-link" href="//support.google.com/youtube/bin/answer.py?hl=en&amp;answer=2952738&amp;rd=1" rel="nofollow" target="_blank">
# <img alt="Socialblade is YouTube Certified" src="/images/certified.png?version=2" title="Socialblade YouTube Certified"/>
# </a>
# </div>
# <h3 style="font-weight: normal; font-size: 1.1em; margin-bottom: 8px; margin-top: 16px;">Helpful Pages</h3>
# <div style="font-size: 10pt;">
# <a class="footer-link" href="//socialblade.com/blog/new-feature-tags-and-locations-3126-2/" target="_blank">Set Tags &amp; Locations for your Profile</a>
# <a class="footer-link" href="/authenticate" target="_blank">Link and Manage Your Profiles</a>
# <a class="footer-link" href="//socialblade.com/blog/nine-years-of-socialblade/" target="_blank">Social Blade's History</a>
# <a class="footer-link" href="/products/query" target="_blank">Find Influencers - Run Reports</a>
# <a class="footer-link" href="/products/subscription" target="_blank">Remove Ads &amp; Support Social Blade</a>
# </div>
# </div>
# </div>
# <div style="float: left; width: 300px; height: 250px;">
# <div style="width: 298px; height: 249px; margin: 0px auto 10px auto;">
# <div style="z-index:10; position:absolute;">
# <div id="cdm-zone-06"></div> </div>
# <div class="socialblade-heartbeat" style="z-index:5; position:absolute; display: none;">
# <div style="width: 298px; height: 248px; background: #d37a74; border: 2px solid #b3382c; text-align: center;">
# <i class="fa fa-exclamation-triangle fa-5x" style="margin-top: 20px; color:#fff;"></i>
# <div style="margin: 0px auto; width: 80%; color:#fff; margin-top: 10px; font-size: 10pt; line-height: 1.5em;">Hello, visitor! Please consider adding SocialBlade.com to your adblock whitelist. Our ads support the development and upkeep of the site. Upgrade to a <a href="/products/subscription" style="color:#fff;">Premium Subscription</a> to load the site without ads.
# 				</div>
# </div><div style="clear: both;"></div>
# </div>
# </div>
# <div style="font-size: 8pt; margin-top: -7px; text-align: center;">Ads by Curse</div>
# </div>
# </div>
# </div>
# <div id="footer-bottom-bar-wrap">
# <div id="footer-bottom-bar">
# <a class="footer-link-2" href="/info/privacy">Privacy Policy</a>
# <a class="footer-link-2" href="/info/terms">Terms of Service</a>
# <a class="footer-link-2" href="/info/team">Meet the Team</a>
# <a class="footer-link-2" href="/info/media">Media Assets</a>
# <a class="footer-link-2" href="/tools">Tools</a>
# <a class="footer-link-2" href="/info">About</a>
# <a class="footer-link-2" href="//support.socialblade.com/" target="_blank">Contact Us</a>
# <span id="footer-microtime">
#
# 		(0.0118s)		</span>
# <div class="float-right">
# 		Copyright ©2008-2019. Social Blade LLC. All Rights Reserved.
# 		</div>
# </div>
# </div>
# <script src="/js/jquery-ui.min.js?version=9001.2123472247" type="text/javascript"></script>
# <script src="/js/search-menu.js?version=9001.2123472247" type="text/javascript"></script>
# <script src="/js/sb.js?version=9001.2123472247" type="text/javascript"></script>
# <script src="/js/cookie.js" type="text/javascript"></script>
# <script src="https://www.google.com/recaptcha/api.js"></script>
# <script src="https://www.google.com/recaptcha/api.js"></script>
# <script src="//code.highcharts.com/highcharts.js"></script>
# <script src="//cdnjs.cloudflare.com/ajax/libs/toastr.js/latest/toastr.min.js"></script>
# <div id="cdm-zone-end"></div>
# </body>
# </html>

# %%
    body = soup.findAll("div",{"class": "table-body"})
    print(body)
# Out:
# [<div class="table-body">
# <div class="table-cell section-rank">1</div>
# <div class="table-cell section-grade"><span style="color:#00bee7;">A++</span></div>
# <div class="table-cell section-med"><a href="/twitter/user/katyperry">katyperry</a></div>
# <div class="table-cell section-lg">KATY PERRY</div>
# <div class="table-cell section-sm">10,002</div>
# <div class="table-cell section-med">107,628,466</div>
# <div class="table-cell section-med">220</div>
# </div>, <div class="table-body">
# <div class="table-cell section-rank">2</div>
# <div class="table-cell section-grade"><span style="color:#00bee7;">A++</span></div>
# <div class="table-cell section-med"><a href="/twitter/user/barackobama">BarackObama</a></div>
# <div class="table-cell section-lg">Barack Obama</div>
# <div class="table-cell section-sm">15,645</div>
# <div class="table-cell section-med">106,838,347</div>
# <div class="table-cell section-med">613,544</div>
# </div>, <div class="table-body">
# <div class="table-cell section-rank">3</div>
# <div class="table-cell section-grade"><span style="color:#00bee7;">A++</span></div>
# <div class="table-cell section-med"><a href="/twitter/user/justinbieber">justinbieber</a></div>
# <div class="table-cell section-lg">Justin Bieber</div>
# <div class="table-cell section-sm">30,491</div>
# <div class="table-cell section-med">105,898,645</div>
# <div class="table-cell section-med">298,264</div>
# </div>, <div class="table-body">
# <div class="table-cell section-rank">4</div>
# <div class="table-cell section-grade"><span style="color:#00bee7;">A++</span></div>
# <div class="table-cell section-med"><a href="/twitter/user/rihanna">rihanna</a></div>
# <div class="table-cell section-lg">Rihanna</div>
# <div class="table-cell section-sm">10,320</div>
# <div class="table-cell section-med">91,833,267</div>
# <div class="table-cell section-med">1,081</div>
# </div>, <div class="table-body">
# <div class="table-cell section-rank">5</div>
# <div class="table-cell section-grade"><span style="color:#00bee7;">A++</span></div>
# <div class="table-cell section-med"><a href="/twitter/user/taylorswift13">taylorswift13</a></div>
# <div class="table-cell section-lg">Taylor Swift</div>
# <div class="table-cell section-sm">217</div>
# <div class="table-cell section-med">83,703,185</div>
# <div class="table-cell section-med">0</div>
# </div>, <div class="table-body">
# <div class="table-cell section-rank">6</div>
# <div class="table-cell section-grade"><span style="color:#00bee7;">A++</span></div>
# <div class="table-cell section-med"><a href="/twitter/user/ladygaga">ladygaga</a></div>
# <div class="table-cell section-lg">Lady Gaga</div>
# <div class="table-cell section-sm">8,964</div>
# <div class="table-cell section-med">78,812,787</div>
# <div class="table-cell section-med">124,883</div>
# </div>, <div class="table-body">
# <div class="table-cell section-rank">7</div>
# <div class="table-cell section-grade"><span style="color:#00bee7;">A++</span></div>
# <div class="table-cell section-med"><a href="/twitter/user/cristiano">Cristiano</a></div>
# <div class="table-cell section-lg">Cristiano Ronaldo</div>
# <div class="table-cell section-sm">3,411</div>
# <div class="table-cell section-med">78,527,212</div>
# <div class="table-cell section-med">51</div>
# </div>, <div class="table-body">
# <div class="table-cell section-rank">8</div>
# <div class="table-cell section-grade"><span style="color:#00bee7;">A++</span></div>
# <div class="table-cell section-med"><a href="/twitter/user/theellenshow">TheEllenShow</a></div>
# <div class="table-cell section-lg">Ellen DeGeneres</div>
# <div class="table-cell section-sm">19,799</div>
# <div class="table-cell section-med">77,962,296</div>
# <div class="table-cell section-med">31,238</div>
# </div>, <div class="table-body">
# <div class="table-cell section-rank">9</div>
# <div class="table-cell section-grade"><span style="color:#00bee7;">A++</span></div>
# <div class="table-cell section-med"><a href="/twitter/user/youtube">YouTube</a></div>
# <div class="table-cell section-lg">YouTube</div>
# <div class="table-cell section-sm">23,494</div>
# <div class="table-cell section-med">71,592,617</div>
# <div class="table-cell section-med">1,036</div>
# </div>, <div class="table-body">
# <div class="table-cell section-rank">10</div>
# <div class="table-cell section-grade"><span style="color:#00bee7;">A++</span></div>
# <div class="table-cell section-med"><a href="/twitter/user/jtimberlake">jtimberlake</a></div>
# <div class="table-cell section-lg">Justin Timberlake</div>
# <div class="table-cell section-sm">4,095</div>
# <div class="table-cell section-med">65,000,525</div>
# <div class="table-cell section-med">291</div>
# </div>, <div class="table-body">
# <div class="table-cell section-rank">11</div>
# <div class="table-cell section-grade"><span style="color:#00bee7;">A++</span></div>
# <div class="table-cell section-med"><a href="/twitter/user/arianagrande">ArianaGrande</a></div>
# <div class="table-cell section-lg">Ariana Grande</div>
# <div class="table-cell section-sm">44,634</div>
# <div class="table-cell section-med">63,670,733</div>
# <div class="table-cell section-med">61,932</div>
# </div>, <div class="table-body">
# <div class="table-cell section-rank">12</div>
# <div class="table-cell section-grade"><span style="color:#00bee7;">A++</span></div>
# <div class="table-cell section-med"><a href="/twitter/user/realdonaldtrump">realDonaldTrump</a></div>
# <div class="table-cell section-lg">Donald J. Trump</div>
# <div class="table-cell section-sm">42,602</div>
# <div class="table-cell section-med">61,581,442</div>
# <div class="table-cell section-med">47</div>
# </div>, <div class="table-body">
# <div class="table-cell section-rank">13</div>
# <div class="table-cell section-grade"><span style="color:#00bee7;">A++</span></div>
# <div class="table-cell section-med"><a href="/twitter/user/kimkardashian">KimKardashian</a></div>
# <div class="table-cell section-lg">Kim Kardashian West</div>
# <div class="table-cell section-sm">29,629</div>
# <div class="table-cell section-med">61,137,442</div>
# <div class="table-cell section-med">146</div>
# </div>, <div class="table-body">
# <div class="table-cell section-rank">14</div>
# <div class="table-cell section-grade"><span style="color:#00bee7;">A++</span></div>
# <div class="table-cell section-med"><a href="/twitter/user/selenagomez">selenagomez</a></div>
# <div class="table-cell section-lg">Selena Gomez</div>
# <div class="table-cell section-sm">4,385</div>
# <div class="table-cell section-med">57,814,832</div>
# <div class="table-cell section-med">1,188</div>
# </div>, <div class="table-body">
# <div class="table-cell section-rank">15</div>
# <div class="table-cell section-grade"><span style="color:#00bee7;">A++</span></div>
# <div class="table-cell section-med"><a href="/twitter/user/ddlovato">ddlovato</a></div>
# <div class="table-cell section-lg">Demi Lovato</div>
# <div class="table-cell section-sm">17,080</div>
# <div class="table-cell section-med">57,439,469</div>
# <div class="table-cell section-med">535</div>
# </div>, <div class="table-body">
# <div class="table-cell section-rank">16</div>
# <div class="table-cell section-grade"><span style="color:#00bee7;">A++</span></div>
# <div class="table-cell section-med"><a href="/twitter/user/britneyspears">britneyspears</a></div>
# <div class="table-cell section-lg">Britney Spears</div>
# <div class="table-cell section-sm">5,628</div>
# <div class="table-cell section-med">56,372,738</div>
# <div class="table-cell section-med">381,863</div>
# </div>, <div class="table-body">
# <div class="table-cell section-rank">17</div>
# <div class="table-cell section-grade"><span style="color:#69ce10;">A+</span></div>
# <div class="table-cell section-med"><a href="/twitter/user/twitter">Twitter</a></div>
# <div class="table-cell section-lg">Twitter</div>
# <div class="table-cell section-sm">10,677</div>
# <div class="table-cell section-med">56,254,842</div>
# <div class="table-cell section-med">140</div>
# </div>, <div class="table-body">
# <div class="table-cell section-rank">18</div>
# <div class="table-cell section-grade"><span style="color:#69ce10;">A+</span></div>
# <div class="table-cell section-med"><a href="/twitter/user/cnnbrk">cnnbrk</a></div>
# <div class="table-cell section-lg">CNN Breaking News</div>
# <div class="table-cell section-sm">66,574</div>
# <div class="table-cell section-med">55,402,266</div>
# <div class="table-cell section-med">121</div>
# </div>, <div class="table-body">
# <div class="table-cell section-rank">19</div>
# <div class="table-cell section-grade"><span style="color:#69ce10;">A+</span></div>
# <div class="table-cell section-med"><a href="/twitter/user/shakira">shakira</a></div>
# <div class="table-cell section-lg">Shakira</div>
# <div class="table-cell section-sm">6,237</div>
# <div class="table-cell section-med">51,292,424</div>
# <div class="table-cell section-med">209</div>
# </div>, <div class="table-body">
# <div class="table-cell section-rank">20</div>
# <div class="table-cell section-grade"><span style="color:#69ce10;">A+</span></div>
# <div class="table-cell section-med"><a href="/twitter/user/jimmyfallon">jimmyfallon</a></div>
# <div class="table-cell section-lg">jimmy fallon</div>
# <div class="table-cell section-sm">11,978</div>
# <div class="table-cell section-med">51,236,102</div>
# <div class="table-cell section-med">8,929</div>
# </div>, <div class="table-body">
# <div class="table-cell section-rank">21</div>
# <div class="table-cell section-grade"><span style="color:#69ce10;">A+</span></div>
# <div class="table-cell section-med"><a href="/twitter/user/narendramodi">narendramodi</a></div>
# <div class="table-cell section-lg">Narendra Modi</div>
# <div class="table-cell section-sm">24,009</div>
# <div class="table-cell section-med">48,330,580</div>
# <div class="table-cell section-med">2,171</div>
# </div>, <div class="table-body">
# <div class="table-cell section-rank">22</div>
# <div class="table-cell section-grade"><span style="color:#69ce10;">A+</span></div>
# <div class="table-cell section-med"><a href="/twitter/user/billgates">BillGates</a></div>
# <div class="table-cell section-lg">Bill Gates</div>
# <div class="table-cell section-sm">3,112</div>
# <div class="table-cell section-med">47,517,921</div>
# <div class="table-cell section-med">198</div>
# </div>, <div class="table-body">
# <div class="table-cell section-rank">23</div>
# <div class="table-cell section-grade"><span style="color:#69ce10;">A+</span></div>
# <div class="table-cell section-med"><a href="/twitter/user/neymarjr">neymarjr</a></div>
# <div class="table-cell section-lg">Neymar Jr</div>
# <div class="table-cell section-sm">41,519</div>
# <div class="table-cell section-med">43,701,606</div>
# <div class="table-cell section-med">750</div>
# </div>, <div class="table-body">
# <div class="table-cell section-rank">24</div>
# <div class="table-cell section-grade"><span style="color:#69ce10;">A+</span></div>
# <div class="table-cell section-med"><a href="/twitter/user/jlo">JLo</a></div>
# <div class="table-cell section-lg">Jennifer Lopez</div>
# <div class="table-cell section-sm">14,735</div>
# <div class="table-cell section-med">43,680,672</div>
# <div class="table-cell section-med">1,686</div>
# </div>, <div class="table-body">
# <div class="table-cell section-rank">25</div>
# <div class="table-cell section-grade"><span style="color:#69ce10;">A+</span></div>
# <div class="table-cell section-med"><a href="/twitter/user/nytimes">nytimes</a></div>
# <div class="table-cell section-lg">The New York Times</div>
# <div class="table-cell section-sm">363,899</div>
# <div class="table-cell section-med">43,644,397</div>
# <div class="table-cell section-med">898</div>
# </div>]

# %%
#loading html data in to a table by choosing rank, grade, user_name,display_name,tweets,followers,following to be displayed
def table(row):
    data = [i.text for i in row if i !=u'\n']
    return dict(rank = int(data[0]), grade = str(data[1]), user_name = str(data[2]), display_name = str(data[3].replace(",","")), tweets = int(data[4].replace(",","")), followers = int(data[5].replace(",","")),following=int(data[6].replace(",","")))

# %%
for i in range(25):
    print(table(body[i]))
# Out:
# {'rank': 1, 'grade': 'A++', 'user_name': 'katyperry', 'display_name': 'KATY PERRY', 'tweets': 10002, 'followers': 107628466, 'following': 220}
# {'rank': 2, 'grade': 'A++', 'user_name': 'BarackObama', 'display_name': 'Barack Obama', 'tweets': 15645, 'followers': 106838347, 'following': 613544}
# {'rank': 3, 'grade': 'A++', 'user_name': 'justinbieber', 'display_name': 'Justin Bieber', 'tweets': 30491, 'followers': 105898645, 'following': 298264}
# {'rank': 4, 'grade': 'A++', 'user_name': 'rihanna', 'display_name': 'Rihanna', 'tweets': 10320, 'followers': 91833267, 'following': 1081}
# {'rank': 5, 'grade': 'A++', 'user_name': 'taylorswift13', 'display_name': 'Taylor Swift', 'tweets': 217, 'followers': 83703185, 'following': 0}
# {'rank': 6, 'grade': 'A++', 'user_name': 'ladygaga', 'display_name': 'Lady Gaga', 'tweets': 8964, 'followers': 78812787, 'following': 124883}
# {'rank': 7, 'grade': 'A++', 'user_name': 'Cristiano', 'display_name': 'Cristiano Ronaldo', 'tweets': 3411, 'followers': 78527212, 'following': 51}
# {'rank': 8, 'grade': 'A++', 'user_name': 'TheEllenShow', 'display_name': 'Ellen DeGeneres', 'tweets': 19799, 'followers': 77962296, 'following': 31238}
# {'rank': 9, 'grade': 'A++', 'user_name': 'YouTube', 'display_name': 'YouTube', 'tweets': 23494, 'followers': 71592617, 'following': 1036}
# {'rank': 10, 'grade': 'A++', 'user_name': 'jtimberlake', 'display_name': 'Justin Timberlake', 'tweets': 4095, 'followers': 65000525, 'following': 291}
# {'rank': 11, 'grade': 'A++', 'user_name': 'ArianaGrande', 'display_name': 'Ariana Grande', 'tweets': 44634, 'followers': 63670733, 'following': 61932}
# {'rank': 12, 'grade': 'A++', 'user_name': 'realDonaldTrump', 'display_name': 'Donald J. Trump', 'tweets': 42602, 'followers': 61581442, 'following': 47}
# {'rank': 13, 'grade': 'A++', 'user_name': 'KimKardashian', 'display_name': 'Kim Kardashian West', 'tweets': 29629, 'followers': 61137442, 'following': 146}
# {'rank': 14, 'grade': 'A++', 'user_name': 'selenagomez', 'display_name': 'Selena Gomez', 'tweets': 4385, 'followers': 57814832, 'following': 1188}
# {'rank': 15, 'grade': 'A++', 'user_name': 'ddlovato', 'display_name': 'Demi Lovato', 'tweets': 17080, 'followers': 57439469, 'following': 535}
# {'rank': 16, 'grade': 'A++', 'user_name': 'britneyspears', 'display_name': 'Britney Spears', 'tweets': 5628, 'followers': 56372738, 'following': 381863}
# {'rank': 17, 'grade': 'A+', 'user_name': 'Twitter', 'display_name': 'Twitter', 'tweets': 10677, 'followers': 56254842, 'following': 140}
# {'rank': 18, 'grade': 'A+', 'user_name': 'cnnbrk', 'display_name': 'CNN Breaking News', 'tweets': 66574, 'followers': 55402266, 'following': 121}
# {'rank': 19, 'grade': 'A+', 'user_name': 'shakira', 'display_name': 'Shakira', 'tweets': 6237, 'followers': 51292424, 'following': 209}
# {'rank': 20, 'grade': 'A+', 'user_name': 'jimmyfallon', 'display_name': 'jimmy fallon', 'tweets': 11978, 'followers': 51236102, 'following': 8929}
# {'rank': 21, 'grade': 'A+', 'user_name': 'narendramodi', 'display_name': 'Narendra Modi', 'tweets': 24009, 'followers': 48330580, 'following': 2171}
# {'rank': 22, 'grade': 'A+', 'user_name': 'BillGates', 'display_name': 'Bill Gates', 'tweets': 3112, 'followers': 47517921, 'following': 198}
# {'rank': 23, 'grade': 'A+', 'user_name': 'neymarjr', 'display_name': 'Neymar Jr', 'tweets': 41519, 'followers': 43701606, 'following': 750}
# {'rank': 24, 'grade': 'A+', 'user_name': 'JLo', 'display_name': 'Jennifer Lopez', 'tweets': 14735, 'followers': 43680672, 'following': 1686}
# {'rank': 25, 'grade': 'A+', 'user_name': 'nytimes', 'display_name': 'The New York Times', 'tweets': 363899, 'followers': 43644397, 'following': 898}

# %%
# performing iterations to obtain all the results
data = []
for tr in body:
    datum = table(tr)
    for a in tr.find_all('a', href= True):
        datum['url'] = a['href']
    data.append(datum)

# %% [markdown]
# ##  Importing data in to pandas

# %%
# storing the result in pandas data frame
df = pd.DataFrame(data)
df
# Out:
#            display_name  followers  following grade  rank  tweets  \
# 0            KATY PERRY  107628466        220   A++     1   10002
# 1          Barack Obama  106838347     613544   A++     2   15645
# 2         Justin Bieber  105898645     298264   A++     3   30491
# 3               Rihanna   91833267       1081   A++     4   10320
# 4          Taylor Swift   83703185          0   A++     5     217
# 5             Lady Gaga   78812787     124883   A++     6    8964
# 6     Cristiano Ronaldo   78527212         51   A++     7    3411
# 7       Ellen DeGeneres   77962296      31238   A++     8   19799
# 8               YouTube   71592617       1036   A++     9   23494
# 9     Justin Timberlake   65000525        291   A++    10    4095
# 10        Ariana Grande   63670733      61932   A++    11   44634
# 11      Donald J. Trump   61581442         47   A++    12   42602
# 12  Kim Kardashian West   61137442        146   A++    13   29629
# 13         Selena Gomez   57814832       1188   A++    14    4385
# 14          Demi Lovato   57439469        535   A++    15   17080
# 15       Britney Spears   56372738     381863   A++    16    5628
# 16              Twitter   56254842        140    A+    17   10677
# 17    CNN Breaking News   55402266        121    A+    18   66574
# 18              Shakira   51292424        209    A+    19    6237
# 19         jimmy fallon   51236102       8929    A+    20   11978
# 20        Narendra Modi   48330580       2171    A+    21   24009
# 21           Bill Gates   47517921        198    A+    22    3112
# 22            Neymar Jr   43701606        750    A+    23   41519
# 23       Jennifer Lopez   43680672       1686    A+    24   14735
# 24   The New York Times   43644397        898    A+    25  363899
#
#                               url        user_name
# 0         /twitter/user/katyperry        katyperry
# 1       /twitter/user/barackobama      BarackObama
# 2      /twitter/user/justinbieber     justinbieber
# 3           /twitter/user/rihanna          rihanna
# 4     /twitter/user/taylorswift13    taylorswift13
# 5          /twitter/user/ladygaga         ladygaga
# 6         /twitter/user/cristiano        Cristiano
# 7      /twitter/user/theellenshow     TheEllenShow
# 8           /twitter/user/youtube          YouTube
# 9       /twitter/user/jtimberlake      jtimberlake
# 10     /twitter/user/arianagrande     ArianaGrande
# 11  /twitter/user/realdonaldtrump  realDonaldTrump
# 12    /twitter/user/kimkardashian    KimKardashian
# 13      /twitter/user/selenagomez      selenagomez
# 14         /twitter/user/ddlovato         ddlovato
# 15    /twitter/user/britneyspears    britneyspears
# 16          /twitter/user/twitter          Twitter
# 17           /twitter/user/cnnbrk           cnnbrk
# 18          /twitter/user/shakira          shakira
# 19      /twitter/user/jimmyfallon      jimmyfallon
# 20     /twitter/user/narendramodi     narendramodi
# 21        /twitter/user/billgates        BillGates
# 22         /twitter/user/neymarjr         neymarjr
# 23              /twitter/user/jlo              JLo
# 24          /twitter/user/nytimes          nytimes

# %% [markdown]
# ##  visualizing the results using Matplotlib

# %%
import seaborn as sns
import matplotlib.pyplot as plt
import matplotlib.style as style
# %matplotlib inline

# %% [markdown]
# ## Bar Graph to show the top followed users

# %%
ax = sns.barplot(x="followers", y="display_name", data= df, color='purple')#palette=("RdPu"))
style.use('ggplot')
plt.title('Top 25 Twitter Users by Followers', fontweight='bold',fontsize =26)
plt.xlabel("millions", fontweight='bold',fontsize =26)
plt.ylabel(" ")
plt.tight_layout()
plt.savefig('followers.png', Transparent = True)

# %% [markdown]
# ## Users with respective tweets

# %%
ax = sns.barplot(x="tweets", y="display_name", data= df, color='purple')#palette=("RdPu"))
style.use('ggplot')
plt.title('users tweets', fontweight='bold',fontsize=26)
plt.xlabel(" thousands ", fontweight='bold',fontsize=26)
plt.ylabel(" ")
plt.tight_layout()
plt.savefig('tweets.png', Transparent = True)

# %% [markdown]
# ## Conclusion

# %% [markdown]
# ### After doing the scrapping using python on twitter we can see the number of followers for top 25 users and their total number of tweets on twiter.
